# %%
import pandas as pd
import numpy as np
from pyexplainer import pyexplainer_pyexplainer
from IPython.display import display, HTML
# Out:
# /home/shuvradeb/Machine Learning/fe_xai/fe_xai_venv/lib/python3.8/site-packages/statsmodels/compat/pandas.py:65: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %%
df = pyexplainer_pyexplainer.load_sample_data()
df.head()
# Out:
#                                                 File  CountDeclMethodPrivate  \
# 0  activemq-console/src/main/java/org/apache/acti...                       0
# 1  activemq-console/src/main/java/org/apache/acti...                       0
# 2  activemq-console/src/main/java/org/apache/acti...                       0
# 3  activemq-console/src/main/java/org/apache/acti...                       0
# 4  activemq-console/src/main/java/org/apache/acti...                       0
#
#    AvgLineCode  CountLine  MaxCyclomatic  CountDeclMethodDefault  \
# 0           10        171              5                       0
# 1            8        123              5                       0
# 2            7        136              5                       0
# 3           29        241             17                       0
# 4           24        212             17                       0
#
#    AvgEssential  CountDeclClassVariable  SumCyclomaticStrict  AvgCyclomatic  \
# ...

# %%
# Prepare the data
df = df.set_index(df["File"])
df = df.drop(["File", "HeuBug", "HeuBugCount", "RealBugCount"], axis=1)
df.head(3)
# Out:
#                                                     CountDeclMethodPrivate  \
# File
# activemq-console/src/main/java/org/apache/activ...                       0
# activemq-console/src/main/java/org/apache/activ...                       0
# activemq-console/src/main/java/org/apache/activ...                       0
#
#                                                     AvgLineCode  CountLine  \
# File
# activemq-console/src/main/java/org/apache/activ...           10        171
# activemq-console/src/main/java/org/apache/activ...            8        123
# activemq-console/src/main/java/org/apache/activ...            7        136
#
#                                                     MaxCyclomatic  \
# File
# activemq-console/src/main/java/org/apache/activ...              5
# activemq-console/src/main/java/org/apache/activ...              5
# activemq-console/src/main/java/org/apache/activ...              5
#
# ...

# %%
df['RealBug'].value_counts()
# Out:
# False    1591
# True      293
# Name: RealBug, dtype: int64

# %%
from pyexplainer.pyexplainer_pyexplainer import AutoSpearman

# Select all rows and all feature columns
# the last col which is label col is not selected
X = df.iloc[:, :-1]  # removing the class or result or dependent var column
total_features = len(X.columns)
print(f"Total feature before autospearman: {total_features}")

# apply feature selection function to our feature DataFrame
X = AutoSpearman(X)
selected = len(X.columns)
print(f"After autospearman: {selected}")

# select all rows and the last label column which is the dependent var column
y = df.iloc[:, -1]


# Display the DataFrame with a label
display(HTML("<h3>Selected Features DataFrame</h3>"))
display(X.head(3))
display(HTML("<h3>Target Column</h3>"))
display(y.head(3))
# Out:
# Total feature before autospearman: 65
# (Part 1) Automatically select non-correlated metrics based on a Spearman rank correlation test
# > Step 1 comparing between CountDeclMethod and CountDeclFunction
# >> CountDeclMethod has the average correlation of 0.433 with other metrics
# >> CountDeclFunction has the average correlation of 0.433 with other metrics
# >> Exclude CountDeclMethod
# > Step 2 comparing between DDEV and MAJOR_COMMIT
# >> DDEV has the average correlation of 0.274 with other metrics
# >> MAJOR_COMMIT has the average correlation of 0.274 with other metrics
# >> Exclude DDEV
# > Step 3 comparing between SumCyclomaticModified and SumCyclomatic
# >> SumCyclomaticModified has the average correlation of 0.501 with other metrics
# >> SumCyclomatic has the average correlation of 0.501 with other metrics
# >> Exclude SumCyclomatic
# > Step 4 comparing between AvgCyclomaticModified and AvgCyclomatic
# ...

# %%
# Split data into train and test set
from sklearn.model_selection import train_test_split
# 70% training and 30% test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# ## Training and Predicting

# %% [markdown]
# ### Train a RandomForest model using sklearn

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=100, max_depth=None, min_samples_split=2, random_state=0)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %% [markdown]
# ### Generate Prediction

# %%
# generate prediction from the model which will return a list of predicted labels
y_preds = rf_model.predict(X_test)
# create a DataFrame which only has predicted label column
y_preds = pd.DataFrame(data={'PredictedBug': y_preds}, index=y_test.index)
y_preds.head(3)
# Out:
#                                                     PredictedBug
# File
# activemq-core/src/main/java/org/apache/activemq...         False
# activemq-core/src/main/java/org/apache/activemq...          True
# activemq-web-console/src/main/java/org/apache/a...         False

# %% [markdown]
# ## Prediction Post Processing
# With only prediction we cannot generate the explanation. Which is why we need to combine the features with the predicted values. Then we will filter out instance where the model prediction was wrong. Because we need to understand from the explanation which features contributed the most during the prediction.

# %% [markdown]
# ### Combine feature cols, label col and the predicted col in testing set

# %%
print(type(y_test))
combined_testing_data = X_test.join(y_test.to_frame())
combined_testing_data = combined_testing_data.join(y_preds)
combined_testing_data.head(3)
total_rows = len(combined_testing_data)
total_rows
# Out:
# <class 'pandas.core.series.Series'>
# 566

# %% [markdown]
# ### Filter out wrongly predicted rows

# %%
correctly_predicted_data = combined_testing_data[
    combined_testing_data["RealBug"] == combined_testing_data["PredictedBug"]
]

correctly_predicted_rows = len(correctly_predicted_data)
print(
    f"The model correctly predicted {round(correctly_predicted_rows/total_rows, 3)*100} % of testing data"
)
# Out:
# The model correctly predicted 91.5 % of testing data

# %% [markdown]
# We focus on the bug file so filter out the non buggy files

# %%
correctly_predicted_bug = correctly_predicted_data[
    correctly_predicted_data["RealBug"] == True
]
len(correctly_predicted_bug)
# Out:
# 50

# %% [markdown]
# ### Define label and feature columns using the new prepared correctly predicted bug dataset

# %%
# Just select all columns except the last two RealBug and PredictedBug
feature_cols = correctly_predicted_data.iloc[:, :-2]
# As the label select one of the remaining two column as both of them are same
label_col = correctly_predicted_data.iloc[:, -2]

# %% [markdown]
# ### Select one row of correctly predicted bug to be explained

# %%
# Decide which row to be selected
selected_row = 0
#  select the row in X_test which contains all of the feature values
X_explain = feature_cols.iloc[[selected_row]]
display(X_explain)
# Select the corresponding label from the DataFrame that we just created above
y_explain = label_col.iloc[[selected_row]]
y_explain
# Out:
#                                                     CountClassDerived  \
# File
# activemq-core/src/main/java/org/apache/activemq...                  0
#
#                                                     RatioCommentToCode  \
# File
# activemq-core/src/main/java/org/apache/activemq...                 0.4
#
#                                                     CountDeclClassVariable  \
# File
# activemq-core/src/main/java/org/apache/activemq...                       0
#
#                                                     CountDeclMethodPublic  \
# File
# activemq-core/src/main/java/org/apache/activemq...                      2
#
#                                                     MAJOR_LINE  OWN_LINE  \
# File
# activemq-core/src/main/java/org/apache/activemq...           2  0.538462
#
#                                                     MINOR_COMMIT  \
# File
# activemq-core/src/main/java/org/apache/activemq...             0
#
# ...

# %% [markdown]
# ## Create rules using pyexplainer and visualize it

# %% [markdown]
# ### Initialize PyExplainer object

# %%
from pyexplainer import pyexplainer_pyexplainer

py_explainer = pyexplainer_pyexplainer.PyExplainer(
    X_train=X_train,
    y_train=y_train,
    indep=X_train.columns,
    dep="RealBug",
    blackbox_model=rf_model,
)

# %% [markdown]
# ### Create rules by triggering explain function under PyExplainer object
#
# This operation is time consuiming as it works with local model?

# %%
rules = py_explainer.explain(
    X_explain=X_explain, y_explain=y_explain, search_function="CrossoverInterpolation"
)
# Out:
# /home/shuvradeb/Machine Learning/fe_xai/fe_xai_venv/lib/python3.8/site-packages/pyexplainer/pyexplainer_pyexplainer.py:888: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_fourty_df = top_fourty_df.append(
# /home/shuvradeb/Machine Learning/fe_xai/fe_xai_venv/lib/python3.8/site-packages/pyexplainer/pyexplainer_pyexplainer.py:888: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_fourty_df = top_fourty_df.append(
# /home/shuvradeb/Machine Learning/fe_xai/fe_xai_venv/lib/python3.8/site-packages/pyexplainer/pyexplainer_pyexplainer.py:920: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_neighbours_similarity_df = final_neighbours_similarity_df.append(
# ...

# %%
rules.keys()
# Out:
# dict_keys(['synthetic_data', 'synthetic_predictions', 'X_explain', 'y_explain', 'indep', 'dep', 'top_k_positive_rules', 'top_k_negative_rules', 'local_rulefit_model'])

# %%
py_explainer.visualise(rules)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_620189/223824580.py in <cell line: 1>()
# ----> 1 py_explainer.visualise(rules)
#
# NameError: name 'py_explainer' is not defined
